# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenthanhTung14/Nguy-nThanhT-ng/blob/main/ngay3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nhan dien
from keras.datasets import cifar100
(x_train, y_train),(x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
x_train.shape
y_train.shape
import matplotlib.pyplot as plt
hinh = x_train[0]
plt.imshow(hinh, cmap = plt.cm.binary)
plt.show
print('Hinh', y_train[100])
# Out:
# Hinh [55]

# %%
from keras.utils import to_categorical

# %%
import matplotlib.pyplot as plt
for i in range(10):
  plt.subplot(3,5, i+1)
  plt.tight_layout()
  plt.imshow(x_train[i], cmap = 'gray', interpolation = 'none')
  plt.title('Hinh'.format(y_train[i]))

  plt.xticks([])
  plt.yticks([])

# %%
#bai nhan dien CIFAR
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
(x_train,y_train),(x_test,y_test)=cifar100.load_data()

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

x_train=x_train.reshape(50000,32*32*3)
x_train=x_train.astype('float32')/255

y_train=to_categorical(y_train,100)
y_test=to_categorical(y_test,100)


model = Sequential()
model.add(Dense(2000, input_shape=(32*32*3,), activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(100, activation = 'softmax'))
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
from keras.datasets import cifar100
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

x_train = x_train.reshape(50000,32*32*3)
x_train = x_train.astype('float32')/255
x_test = x_test.reshape(10000,32*32*3)
x_test = x_test.astype('float32')/255

y_train = to_categorical(y_train,100)
y_test = to_categorical(y_test,100)

model = Sequential()
model.add(Dense(2000, input_shape=(32*32*3,), activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(100, activation = 'softmax'))
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
#PHAN CAU LENH TRAIN
model.compile(optimizer='rmsprop', loss= 'categorical_crossentropy', metrics= ['accuracy'])
model.fit(x_train, y_train, epochs = 10, batch_size = 128)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_acc)
print(test_loss)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 67s 168ms/step - loss: 4.2378 - accuracy: 0.0706
# Epoch 2/10
# 391/391 [==============================] - 70s 178ms/step - loss: 3.7260 - accuracy: 0.1313
# Epoch 3/10
# 391/391 [==============================] - 69s 176ms/step - loss: 3.5496 - accuracy: 0.1627
# Epoch 4/10
# 391/391 [==============================] - 68s 174ms/step - loss: 3.4129 - accuracy: 0.1882
# Epoch 5/10
# 391/391 [==============================] - 67s 170ms/step - loss: 3.3155 - accuracy: 0.2045
# Epoch 6/10
# 391/391 [==============================] - 72s 185ms/step - loss: 3.2196 - accuracy: 0.2222
# Epoch 7/10
# 391/391 [==============================] - 68s 173ms/step - loss: 3.1345 - accuracy: 0.2414
# Epoch 8/10
# 391/391 [==============================] - 65s 167ms/step - loss: 3.0623 - accuracy: 0.2513
# Epoch 9/10
# 391/391 [==============================] - 62s 159ms/step - loss: 2.9903 - accuracy: 0.2667
# Epoch 10/10
# 391/391 [==============================] - 62s 158ms/step - loss: 2.9136 - accuracy: 0.2827
# 313/313 [==============================] - 7s 22ms/step - loss: 3.3552 - accuracy: 0.2203
# 0.22030000388622284
# 3.355165719985962

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save('/content/drive/MyDrive/cifar100.h5')
