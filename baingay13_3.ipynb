# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenthanhTung14/Nguy-nThanhT-ng/blob/main/baingay13_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linecar_model

url = 'mtcars.csv'
data = pd.read_csv(url)

X = data.drop(data.columns[[0,2]],axis = 1)
data.plot(kind = 'scatter', x = 'wt',y='mpg', figsize = (12,9), color = 'black')
model = linecar_model.LinecarRegression()
model.fit(X=pd.DataFrame(data'wt'),y = data['mpgmpg'])
print(model.intercept_)
print(model.coef_)
model.score(X,y)
y_prel= model.predict(X)
vesidual = data['mpy'] - y_pred
vesidual.describe()
data.plot(kind = 'scatter')
plt.plot(data[])
# Out:
#   File "<ipython-input-39-6c0ae3453261>", line 11
#     model.fit(X=pd.DataFrame(data'wt'),y = data['mpgmpg'])
#                                  ^
# SyntaxError: invalid syntax

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4, data['wt']**5, data['wt']**6, data['wt']**7, data['wt']**8, data['wt']**9, data['wt']**10]).T     #Gồm 1 cột x và 1 cột X bình phương, a1x + a2x^2 + b, T nghich dao
model.fit(X, y = data['mpg'])
print('Intercept cua mo hinh bac 10: ')
print(model.intercept_)
print('Coeffient cua mo hinh bac 10: ')
print(model.coef_)
print('Do chinh xac cua mo hinh: ')
print(model.score(X, y =data['mpg']))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10]).T
y_pred = model.predict(X = predictor)
data.plot(kind='scatter', x='wt', y='mpg', figsize = (9,9), color = 'green', xlim = (0,7))
plt.plot(range, y_pred, color = 'pink')
# Out:
# Intercept cua mo hinh bac 10:
# -14921.11995188375
# Coeffient cua mo hinh bac 10:
# [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Do chinh xac cua mo hinh:
# 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2]).T
model.fit(X, y = data['mpg'])
print('Intercept cua mo hinh bac 2')
print(model.intercept_)
print('Coeffient cua mo hinh bac 2:')
print(model.coef_)
print('Do chinh xac cua mo hinh')
print(model.score(X, y))
# Out:
# Intercept cua mo hinh bac 2
# 49.93081094945181
# Coeffient cua mo hinh bac 2:
# [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f47672009e58> in <module>
#      11 print(model.coef_)
#      12 print('Do chinh xac cua mo hinh')
# ---> 13 print(model.score(X, y))
#
# NameError: name 'y' is not defined

# %%
from scipy.sparse import rand
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

vange = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2]).T
y_prel = model.predict(X=predictor)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0, 7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
vange = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([vange, vange**2]).T
y_p = model.predict(X = predictor)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0, 7))
plt.plot(vange, y_p, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
vange = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([vange, vange**2]).T
y_p = model.predict(X = predictor)
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0, 7))
plt.plot(vange, y_p, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (3.5.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
y = data['mpg']
model.fit(X, y)
print('Intercept của mô hình bậc 2: ')
print(model.intercept_)
print('coeffient của mô hình bậc 2: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X,y))
# Out:
# Intercept của mô hình bậc 2:
# 49.93081094945181
# coeffient của mô hình bậc 2:
# [-13.38033708   1.17108689]
# Độ chính xác của mô hình:
# 0.8190613581384094

# %%
import numpy as np
import matplotlib.pyplot as plt

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X = predictor) 
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-6b57a688a288> in <module>
#       4 range = np.arange(1.5, 5.5, 0.1)
#       5 predictor = pd.DataFrame([range, range**2]).T
# ----> 6 y_pred = model.predict(X = predictor)
#       7 data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
#       8 plt.plot(range, y_pred, color = 'red')
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     567
#     568         if not no_val_X and check_params.get("ensure_2d", True):
# --> 569             self._check_n_features(X, reset=reset)
#     570
#     571         return out
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     368
#     369         if n_features != self.n_features_in_:
# --> 370             raise ValueError(
#     371                 f"X has {n_features} features, but {self.__class__.__name__} "
#     372                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 2 features, but LinearRegression is expecting 10 features as input.

# %%
import numpy as np
import matplotlib.pyplot as plt

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X = predictor) 
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-6b57a688a288> in <module>
#       4 range = np.arange(1.5, 5.5, 0.1)
#       5 predictor = pd.DataFrame([range, range**2]).T
# ----> 6 y_pred = model.predict(X = predictor)
#       7 data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
#       8 plt.plot(range, y_pred, color = 'red')
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     567
#     568         if not no_val_X and check_params.get("ensure_2d", True):
# --> 569             self._check_n_features(X, reset=reset)
#     570
#     571         return out
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     368
#     369         if n_features != self.n_features_in_:
# --> 370             raise ValueError(
#     371                 f"X has {n_features} features, but {self.__class__.__name__} "
#     372                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 2 features, but LinearRegression is expecting 10 features as input.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
data = pd.read_csv('50_Startups.csv')
data.head()
sns.pairplot(data)
corr = data.corr()
sns.heatmap(corr,annot=True)
X= data.drop('Profit',axis= True)
y = data['Profit']
X.head()
from sklearn.preprocessing import StandardScaler
SC= StandardScaler()
X= SC.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.2,radom_state= 0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-42e88650d73c> in <module>
#      15 X= SC.fit_transform(X)
#      16 from sklearn.model_selection import train_test_split
# ---> 17 X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.2,radom_state= 0)
#      18 X_train.shape
#      19 X_test.shape
#
# TypeError: train_test_split() got an unexpected keyword argument 'radom_state'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
data = pd.read_csv('50_Startups.csv')
data.head()
sns.pairplot(data)
corr = data.corr()
sns.heatmap(corr,annot=True)
X= data.drop('Profit',axis= True)
y = data['Profit']
X.head()

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test).round(1)
calculation = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predicted Profit'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-6bce28629221> in <module>
#      14 from sklearn.linear_model import LinearRegression
#      15 regressor = LinearRegression()
# ---> 16 regressor.fit(X_train,y_train)
#      17 y_pred = regressor.predict(X_test).round(1)
#      18 calculation = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predicted Profit'])
#
# NameError: name 'X_train' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
data = pd.read_csv('Advertising.csv')
data.head()
sns.pairplot(data)
corr = data.corr()
sns.heatmap(corr,annot=True)
X= data.drop('sales',axis= True)
y = data['sales']
X.head()
from sklearn.preprocessing import StandardScaler
SC= StandardScaler()
X= SC.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.2,radom_state= 0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-088b6e8982e3> in <module>
#      15 X= SC.fit_transform(X)
#      16 from sklearn.model_selection import train_test_split
# ---> 17 X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.2,radom_state= 0)
#      18 X_train.shape
#      19 X_test.shape
#
# TypeError: train_test_split() got an unexpected keyword argument 'radom_state'
