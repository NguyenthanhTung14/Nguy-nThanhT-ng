# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenthanhTung14/Nguy-nThanhT-ng/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#thu nghiem
from keras.utils import load_img
from keras.utils import img_to_array
import matplotlib.pyplot as plt
import numpy as np

img = load_img('/content/drive/MyDrive/Colab Notebooks/cifar100/sunflower.jpg', target_size=(32, 32, 3))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img), axis=-1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c07f8b4de079> in <cell line: 7>()
#       5 import numpy as np
#       6
# ----> 7 img = load_img('/content/drive/MyDrive/Colab Notebooks/cifar100/sunflower.jpg', target_size=(32, 32, 3))
#       8 plt.imshow(img)
#       9 img = img_to_array(img)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/cifar100/sunflower.jpg'

# %%
#MTCNN 
from matplotlib import pyplot as plt
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/FILE_ANH_AI/ảnh mặt.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)

'''
box[x, y, width, height]
confidence (accuracy)
keypoints
'''
# Out:
# ...
# 3/3 [==============================] - 0s 40ms/step
# {'box': [1672, 1115, 739, 935], 'confidence': 0.9999973177909851, 'keypoints': {'left_eye': (1795, 1480), 'right_eye': (2112, 1469), 'nose': (1882, 1661), 'mouth_left': (1829, 1846), 'mouth_right': (2090, 1853)}}
# {'box': [1195, 569, 248, 324], 'confidence': 0.999995768070221, 'keypoints': {'left_eye': (1282, 690), 'right_eye': (1395, 699), 'nose': (1353, 761), 'mouth_left': (1281, 812), 'mouth_right': (1385, 818)}}
# {'box': [2003, 456, 416, 506], 'confidence': 0.999994695186615, 'keypoints': {'left_eye': (2103, 661), 'right_eye': (2291, 633), 'nose': (2202, 735), 'mouth_left': (2122, 828), 'mouth_right': (2328, 798)}}
# {'box': [1812, 109, 269, 345], 'confidence': 0.9999846816062927, 'keypoints': {'left_eye': (1885, 253), 'right_eye': (2008, 246), 'nose': (1946, 323), 'mouth_left': (1884, 366), 'mouth_right': (2011, 361)}}
# ...

# %%
pip install MTCNN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Nhận diện bằng MTCNNMTCNN
from matplotlib import pyplot as plt
from mtcnn import MTCNN

filename = '/content/drive/MyDrive/FILE_ANH_AI/ảnh mặt.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y, width, height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  for key,value in face ['keypoints'].items():
    dot= plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 3/3 [==============================] - 0s 38ms/step

# %%
plt.savefig('/content/drive/MyDrive/FILE_ANH_AI/nhandienmat.jpg')
