# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenthanhTung14/Nguy-nThanhT-ng/blob/main/ngay3_4_bai2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img,img_to_array

# %%
img=load_img('/content/drive/MyDrive/z3862734560584_30c48332a0b73d2034401617ce4635dc.jpg')
plt.imshow(img)
plt.show()

# %%
img=load_img('/content/drive/MyDrive/z3862734560584_30c48332a0b73d2034401617ce4635dc.jpg',target_size=(32,32))
plt.imshow(img)

# %%
import numpy as np
from keras.models import Sequential
img = img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
np.argmax(model100.predict(img),axis=-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-42185fe4d40a> in <cell line: 6>()
#       4 img=img.astype('float32')
#       5 img=img/255
# ----> 6 np.argmax(model100.predict(img),axis=-1)
#
# NameError: name 'model100' is not defined

# %%
from matplotlib.image import imread 
folder=''
for i in range(25):
  plt.subplot(5,5,i+1)
  filename= folder + 'A' + str(i) + '.jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show()
